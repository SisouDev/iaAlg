# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from statsmodels.stats.diagnostic import lilliefors
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
import warnings

# %% [markdown]
# **Base de dados**

# %%
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(
    '../data/house/housing.csv', sep = ',',
    encoding = 'iso-8859-1'
)

# %% [markdown]
# # Exploração e tratamento dos dados #
# **Atributos Previsores**
#
# <span style="font-size: 14px;">
#
# - RM: é o número médio de cômodos entre os imóveis no bairro. </br>
#
# - LSTAT: é a porcentagem de proprietários no bairro considerados de "classe baixa".
#
# - PTRATIO: é a razão entre estudantes e professores nas escolas de ensino fundamental e médio no bairro.
# </span>
#
# **Variável alvo**
#
# - MEDV: valor médio das casas

# %% [markdown]
# ## Analise de atributos e tipos ##

# %% [markdown]
# **Valores missing**

# %%
df.isnull().sum()
# Out:
# RM         0
# LSTAT      0
# PTRATIO    0
# MEDV       0
# dtype: int64

# %% [markdown]
# **Análise dos tipos de atributos**

# %%
df.shape
# Out:
# (2340, 4)

# %%
df.dtypes
# Out:
# RM         float64
# LSTAT      float64
# PTRATIO    float64
# MEDV       float64
# dtype: object

# %% [markdown]
# **Dados Estatísticos**

# %%
df.describe()
# Out:
#                 RM        LSTAT      PTRATIO          MEDV
# count  2340.000000  2340.000000  2340.000000  2.340000e+03
# mean      6.335303     8.164996    17.729274  5.339491e+05
# std       0.493287     5.993575     1.726801  1.493607e+05
# min       3.561000     1.980000    12.600000  1.050000e+05
# 25%       6.009000     3.740000    16.600000  4.326000e+05
# 50%       6.335000     5.250000    16.600000  5.250000e+05
# 75%       6.635000    11.280000    19.200000  6.468000e+05
# max       8.398000    37.970000    22.000000  1.024800e+06

# %% [markdown]
# ## Análise dos outliers ##

# %% [markdown]
# **Número médio de cômodos por casa no bairro**

# %%
boxplot = px.box(df, y = "RM", width=600, height=400, boxmode='overlay', color_discrete_sequence=["firebrick"])
boxplot.show()

# %% [markdown]
# **Proprietários classe baixa no bairro**

# %%
boxplot = px.box(df, y = "LSTAT", width=600, height=400, boxmode='overlay', color_discrete_sequence=["blueviolet"])
boxplot.show()

# %% [markdown]
# **Razão entre n. de alunos e professores no bairro**

# %%
boxplot = px.box(df, y = "PTRATIO", width=600, height=400, boxmode='overlay', color_discrete_sequence=["orange"])
boxplot.show()

# %% [markdown]
# **Valor médio das casas**

# %%
boxplot = px.box(df, y = "MEDV", width=600, height=400, boxmode='overlay', color_discrete_sequence=["crimson"])
boxplot.show()

# %% [markdown]
# ## Gráficos de dispersão ##

# %% [markdown]
# **Número médio de cômodos por casa no bairro**

# %%
plt.figure(figsize=(6, 4))
sns.scatterplot(data=df, x="RM", y="MEDV", color='crimson')

sns.regplot(data=df, x="RM", y="MEDV", scatter=False, color='black')

plt.title('Correlação entre Quantidade de cômodos e Valor médio')
plt.xlabel('Quantidade de cômodos')
plt.ylabel('Valor médio')
plt.grid(True)

plt.show()

# %% [markdown]
# **Proprietários classe baixa no bairro**

# %%
plt.figure(figsize=(6, 4))
sns.scatterplot(data=df, x="LSTAT", y="MEDV", color='orange')

sns.regplot(data=df, x="LSTAT", y="MEDV", scatter=False, color='blue')

plt.title('Correlação entre classe baixa e Valor médio')
plt.xlabel('Porcentagem de pessoas classe baixa')
plt.ylabel('Valor médio')
plt.grid(True)
plt.show()

# %% [markdown]
# **Razão entre n. de alunos e professores no bairro**

# %%
plt.figure(figsize=(6, 4))
sns.scatterplot(data=df, x="PTRATIO", y="MEDV", color='violet')

sns.regplot(data=df, x="PTRATIO", y="MEDV", scatter=False, color='green')

plt.title('Correlação entre Quantidade de alunos por professor e Valor médio')
plt.xlabel('Quantidade de alunos por professor')
plt.ylabel('Valor médio')
plt.grid(True)
plt.show()

# %%
sns.pairplot(df, height=2);

# %% [markdown]
# ## Análise da Normalidade ##

# %% [markdown]
# ### Gráfico QQ-Plot ###

# %% [markdown]
# **Valor médio das casas no bairro**

# %%
stats.probplot(df['MEDV'], dist = 'norm', plot = plt)
plt.title("Normal Q-Q Plot")
plt.show()

# %%
hist = px.histogram(df, x = "MEDV", nbins = 60)
hist.update_layout(width = 600, height = 400, title_text = "Média dos valores")
hist.show()

# %% [markdown]
# **Número médio de cômodos por casa**

# %%
stats.probplot(df['RM'], dist = 'norm', plot = plt)
plt.title("Normal Q-Q Plot")
plt.show()

# %%
hist = px.histogram(df, x = "RM", nbins = 60)
hist.update_layout(width = 600, height = 400, title_text = "Cômodos por casa")
hist.show()

# %% [markdown]
# **Proprietários classe baixa no bairro**

# %%
stats.probplot(df['LSTAT'], dist = 'norm', plot = plt)
plt.title("Normal Q-Q Plot")
plt.show()

# %%
hist = px.histogram(df, x = "LSTAT", nbins = 60)
hist.update_layout(width = 600, height = 400, title_text = "Porcentagem de pessoas classe baixa")
hist.show()

# %% [markdown]
# **Razão entre n. de alunos e professores no bairro**

# %%
stats.probplot(df['PTRATIO'], dist = 'norm', plot = plt)
plt.title("Normal Q-Q Plot")
plt.show()

# %%
hist = px.histogram(df, x = "PTRATIO", nbins = 60)
hist.update_layout(width = 600, height = 400, title_text = "Quantidade de alunos por professor")
hist.show()

# %% [markdown]
# ## Teste Estatístico ##
# <span style="font-size: 14px;">
#
# **HO = Distribuição normal:** p-valor > 0.05 </br></br>
# **HA = Distribuição não normal:** p-valor < = 0.05
# </span>

# %% [markdown]
# **MEDV**

# %%
estatistica, p = stats.shapiro(df.MEDV)
print("Estatística do teste: {:.4f}".format(estatistica))
print("p-valor: {:.4e}".format(p))
# Out:
# Estatística do teste: 0.9928
# p-valor: 2.4282e-09

# %%
estatistica, p = lilliefors(df.MEDV, dist = 'norm')
print("Estatística do teste: {:.4f}".format(estatistica))
print("p-valor: {:.4e}".format(p))
# Out:
# Estatística do teste: 0.0585
# p-valor: 1.0000e-03

# %% [markdown]
# **RM**

# %%
estatistica, p = stats.shapiro(df.RM)
print("Estatística do teste: {:.4f}".format(estatistica))
print("p-valor: {:.4e}".format(p))
# Out:
# Estatística do teste: 0.9827
# p-valor: 3.0274e-16

# %%
estatistica, p = lilliefors(df.RM, dist = 'norm')
print("Estatística do teste: {:.4f}".format(estatistica))
print("p-valor: {:.4e}".format(p))
# Out:
# Estatística do teste: 0.0425
# p-valor: 1.0000e-03

# %% [markdown]
# **LSTAT**

# %%
estatistica, p = stats.shapiro(df.LSTAT)
print("Estatística do teste: {:.4f}".format(estatistica))
print("p-valor: {:.4e}".format(p))
# Out:
# Estatística do teste: 0.7768
# p-valor: 8.2119e-49

# %%
estatistica, p = lilliefors(df.LSTAT, dist = 'norm')
print("Estatística do teste: {:.4f}".format(estatistica))
print("p-valor: {:.4e}".format(p))
# Out:
# Estatística do teste: 0.2039
# p-valor: 1.0000e-03

# %% [markdown]
# **PTRATIO**

# %%
estatistica, p = stats.shapiro(df.PTRATIO)
print("Estatística do teste: {:.4f}".format(estatistica))
print("p-valor: {:.4e}".format(p))
# Out:
# Estatística do teste: 0.8185
# p-valor: 1.7000e-45

# %%
estatistica, p = lilliefors(df.PTRATIO, dist = 'norm')
print("Estatística do teste: {:.4f}".format(estatistica))
print("p-valor: {:.4e}".format(p))
# Out:
# Estatística do teste: 0.3071
# p-valor: 1.0000e-03

# %% [markdown]
# ## Correlação Linear ##
#
# <span style="font-size: 13px;">
# <li><strong>Coeficiente de Pearson </strong> -> Distribuição normal</li> </br>
# <li><strong>Coeficiente de Spearman</strong> -> Distribuição <strong>não</strong> normal</li></br>
# <li><strong>Coeficiente de Kendall</strong> -> Distribuição <strong>não</strong> normal</li>
# </span>

# %% [markdown]
# **Pearson**

# %%
coef, p = stats.pearsonr(df.MEDV, df.RM)
print('Coeficiente de correlação: {:.2f}'.format(coef))
print('p-valor: {:.2e}'.format(p))
# Out:
# Coeficiente de correlação: 0.70
# p-valor: 0.00e+00

# %% [markdown]
# **Spearman** </br>
#
# *Iremos usá-lo*
#
# <span style="font-size: 13px;">
# <li>Coeficiente de correlação: 0.73 -> Uma correlação de 0.73 é considerada moderadamente forte.</li> </br>
# <li>p-valor: 0.00e+00O -> p-valor gerado é muito baixo e indica que há evidências estatisticamente significativas para rejeitar a hipótese nula de que não há correlação entre as duas variáveis.
# Em outras palavras,<strong> há uma forte correlação entre as variáveis MEDV e RM.</strong> </li>
# </span>

# %%
coef, p = stats.spearmanr(df.MEDV, df.RM)
print('Coeficiente de correlação: {:.2f}'.format(coef))
print('p-valor: {:.2e}'.format(p))
# Out:
# Coeficiente de correlação: 0.73
# p-valor: 0.00e+00

# %% [markdown]
# **Kendall**

# %%
coef, p = stats.kendalltau(df.MEDV, df.RM)
print('Coeficiente de correlação: {:.2f}'.format(coef))
print('p-valor: {:.2e}'.format(p))
# Out:
# Coeficiente de correlação: 0.53
# p-valor: 0.00e+00

# %%
correlacoes = df.corr(method = 'spearman')
correlacoes
# Out:
#                RM     LSTAT   PTRATIO      MEDV
# RM       1.000000 -0.347137 -0.155367  0.731275
# LSTAT   -0.347137  1.000000  0.550828 -0.698332
# PTRATIO -0.155367  0.550828  1.000000 -0.489611
# MEDV     0.731275 -0.698332 -0.489611  1.000000

# %%
plt.figure()
sns.heatmap(correlacoes, annot = True);

# %% [markdown]
# # Regressão Polinomial #
#
# <span style="font-size: 13px;">
#
# **O que é Regressão Polinomial?**
#
# A regressão polinomial é uma extensão da regressão linear, onde a relação entre a variável independente (X) e a variável dependente (Y) é modelada como um polinômio de grau n.
#
# **A equação geral da regressão polinomial é dada por:**
#
# $ Y = β0 + β1*X + β2*X^2 + ... + βn*X^n + ε $
#
# Cada termo do polinômio $(X^k)$ representa uma potência de X elevada a um determinado grau $k$.
#
# Onde:
# - $Y$ é a variável dependente
# - $X$ é a variável independente
# - $β0, β1,$ ..., $βn$ são os coeficientes do polinômio
# - $ε$ é o erro aleatório
#
# **Parâmetros da Regressão Polinomial**
#
# Os principais parâmetros da regressão polinomial são:
# - Grau do Polinômio (n): Determina o grau do polinômio a ser ajustado aos dados. Um maior grau pode levar a um ajuste mais flexível, mas também aumenta o risco </br> de overfitting.
#  O grau do polinômio (n) determina a complexidade do modelo. Um grau maior permite ao modelo capturar relações mais complexas nos dados, </br> mas também aumenta o risco de overfitting, onde o modelo se ajusta demais aos dados de treinamento e não generaliza bem para novos dados.
# - Regularização: Alguns modelos de regressão polinomial podem incluir termos de regularização para evitar overfitting.
#
# **Para implementar a regressão polinomial em Python, podemos usar bibliotecas como NumPy e scikit-learn. O processo geral envolve:**
# 1. Preparar os dados
# 2. Transformar os recursos para incluir termos polinomiais
# 3. Ajustar o modelo de regressão linear aos dados transformados
# 4. Avaliar o desempenho do modelo
#
# </span>

# %% [markdown]
# ## Separação de variáveis ##

# %%
x1 = df.iloc[:, 0:1].values

# %%
y = df.iloc[:, 3].values

# %% [markdown]
# ### Separação em treino e teste ###

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x1, y, test_size = 0.3, random_state = 5
)

# %%
x_train.shape, y_train.shape
# Out:
# ((1638, 1), (1638,))

# %%
x_test.shape, y_test.shape
# Out:
# ((702, 1), (702,))

# %% [markdown]
# ### Pré-processamento ###

# %%
grau_poly = PolynomialFeatures(degree = 2)

# %% [markdown]
# **Ajuste para polinomial**

# %%
x_poly = grau_poly.fit_transform(x_train)
x_poly
# Out:
# array([[ 1.      ,  6.525   , 42.575625],
#        [ 1.      ,  5.936   , 35.236096],
#        [ 1.      ,  6.377   , 40.666129],
#        ...,
#        [ 1.      ,  5.362   , 28.751044],
#        [ 1.      ,  6.982   , 48.748324],
#        [ 1.      ,  6.511   , 42.393121]])

# %%
polynomial = LinearRegression()

# %% [markdown]
# **Treinamento**

# %%
polynomial.fit(x_poly, y_train);

# %%
previsoes_train = polynomial.predict(x_poly)

# %%
polynomial.coef_
# Out:
# array([      0.        , -368149.65457792,   45764.86999412])

# %%
polynomial.intercept_
# Out:
# 1018214.1924397952

# %% [markdown]
# **Equação gerada:**
#
# <span style="font-size: 14px;">
#
# $ \text{Valor} = (1018214.19) - (368149.65 \times RM) + (45764.86 \times RM^2) $
#
# </span>

# %% [markdown]
# ### Gráfico ###

# %%
numeros = np.linspace(3, 9.84, 1638)

# %%
valor = 1018214.19 - 368149.65 * numeros + 45764.86*numeros**2

# %%
plt.scatter(x_train, y_train, s = 8, alpha = 0.5,  c = "crimson")
plt.xlabel("Quantidade de cômodos")
plt.ylabel("Previsão dos valores das casas: dados de treino")
plt.plot(numeros, valor);

# %% [markdown]
# **Previsões para valores distintos**

# %%
comodos = 6
valor = 1018214.19 - 368149.65 * comodos + 45764.86*comodos**2
valor
# Out:
# 456851.24999999953

# %% [markdown]
# **Coeficiente de determinação dos dados de treino**

# %%
polynomial.score(x_poly, y_train)
# Out:
# 0.5233623285490602

# %% [markdown]
# #### Teste ####

# %%
numeros2 = np.linspace(3, 8.88, 702)
numeros2
# Out:
# array([3.        , 3.00838802, 3.01677603, 3.02516405, 3.03355207,
#        3.04194009, 3.0503281 , 3.05871612, 3.06710414, 3.07549215,
#        3.08388017, 3.09226819, 3.10065621, 3.10904422, 3.11743224,
#        3.12582026, 3.13420827, 3.14259629, 3.15098431, 3.15937233,
#        3.16776034, 3.17614836, 3.18453638, 3.19292439, 3.20131241,
#        3.20970043, 3.21808845, 3.22647646, 3.23486448, 3.2432525 ,
#        3.25164051, 3.26002853, 3.26841655, 3.27680456, 3.28519258,
#        3.2935806 , 3.30196862, 3.31035663, 3.31874465, 3.32713267,
#        3.33552068, 3.3439087 , 3.35229672, 3.36068474, 3.36907275,
#        3.37746077, 3.38584879, 3.3942368 , 3.40262482, 3.41101284,
#        3.41940086, 3.42778887, 3.43617689, 3.44456491, 3.45295292,
#        3.46134094, 3.46972896, 3.47811698, 3.48650499, 3.49489301,
#        3.50328103, 3.51166904, 3.52005706, 3.52844508, 3.5368331 ,
#        3.54522111, 3.55360913, 3.56199715, 3.57038516, 3.57877318,
#        3.5871612 , 3.59554922, 3.60393723, 3.61232525, 3.62071327,
#        3.62910128, 3.6374893 , 3.64587732, 3.65426534, 3.66265335,
#        3.67104137, 3.67942939, 3.6878174 , 3.69620542, 3.70459344,
#        3.71298146, 3.72136947, 3.72975749, 3.73814551, 3.74653352,
#        3.75492154, 3.76330956, 3.77169757, 3.78008559, 3.78847361,
#        3.79686163, 3.80524964, 3.81363766, 3.82202568, 3.83041369,
#        3.83880171, 3.84718973, 3.85557775, 3.86396576, 3.87235378,
#        3.8807418 , 3.88912981, 3.89751783, 3.90590585, 3.91429387,
#        3.92268188, 3.9310699 , 3.93945792, 3.94784593, 3.95623395,
#        3.96462197, 3.97300999, 3.981398  , 3.98978602, 3.99817404,
#        4.00656205, 4.01495007, 4.02333809, 4.03172611, 4.04011412,
#        4.04850214, 4.05689016, 4.06527817, 4.07366619, 4.08205421,
#        4.09044223, 4.09883024, 4.10721826, 4.11560628, 4.12399429,
#        4.13238231, 4.14077033, 4.14915835, 4.15754636, 4.16593438,
#        4.1743224 , 4.18271041, 4.19109843, 4.19948645, 4.20787447,
#        4.21626248, 4.2246505 , 4.23303852, 4.24142653, 4.24981455,
#        4.25820257, 4.26659058, 4.2749786 , 4.28336662, 4.29175464,
#        4.30014265, 4.30853067, 4.31691869, 4.3253067 , 4.33369472,
#        4.34208274, 4.35047076, 4.35885877, 4.36724679, 4.37563481,
#        4.38402282, 4.39241084, 4.40079886, 4.40918688, 4.41757489,
#        4.42596291, 4.43435093, 4.44273894, 4.45112696, 4.45951498,
#        4.467903  , 4.47629101, 4.48467903, 4.49306705, 4.50145506,
#        4.50984308, 4.5182311 , 4.52661912, 4.53500713, 4.54339515,
#        4.55178317, 4.56017118, 4.5685592 , 4.57694722, 4.58533524,
#        4.59372325, 4.60211127, 4.61049929, 4.6188873 , 4.62727532,
#        4.63566334, 4.64405136, 4.65243937, 4.66082739, 4.66921541,
#        4.67760342, 4.68599144, 4.69437946, 4.70276748, 4.71115549,
#        4.71954351, 4.72793153, 4.73631954, 4.74470756, 4.75309558,
#        4.76148359, 4.76987161, 4.77825963, 4.78664765, 4.79503566,
#        4.80342368, 4.8118117 , 4.82019971, 4.82858773, 4.83697575,
#        4.84536377, 4.85375178, 4.8621398 , 4.87052782, 4.87891583,
#        4.88730385, 4.89569187, 4.90407989, 4.9124679 , 4.92085592,
#        4.92924394, 4.93763195, 4.94601997, 4.95440799, 4.96279601,
#        4.97118402, 4.97957204, 4.98796006, 4.99634807, 5.00473609,
#        5.01312411, 5.02151213, 5.02990014, 5.03828816, 5.04667618,
#        5.05506419, 5.06345221, 5.07184023, 5.08022825, 5.08861626,
#        5.09700428, 5.1053923 , 5.11378031, 5.12216833, 5.13055635,
#        5.13894437, 5.14733238, 5.1557204 , 5.16410842, 5.17249643,
#        5.18088445, 5.18927247, 5.19766049, 5.2060485 , 5.21443652,
#        5.22282454, 5.23121255, 5.23960057, 5.24798859, 5.2563766 ,
#        5.26476462, 5.27315264, 5.28154066, 5.28992867, 5.29831669,
#        5.30670471, 5.31509272, 5.32348074, 5.33186876, 5.34025678,
#        5.34864479, 5.35703281, 5.36542083, 5.37380884, 5.38219686,
#        5.39058488, 5.3989729 , 5.40736091, 5.41574893, 5.42413695,
#        5.43252496, 5.44091298, 5.449301  , 5.45768902, 5.46607703,
#        5.47446505, 5.48285307, 5.49124108, 5.4996291 , 5.50801712,
#        5.51640514, 5.52479315, 5.53318117, 5.54156919, 5.5499572 ,
#        5.55834522, 5.56673324, 5.57512126, 5.58350927, 5.59189729,
#        5.60028531, 5.60867332, 5.61706134, 5.62544936, 5.63383738,
#        5.64222539, 5.65061341, 5.65900143, 5.66738944, 5.67577746,
#        5.68416548, 5.6925535 , 5.70094151, 5.70932953, 5.71771755,
#        5.72610556, 5.73449358, 5.7428816 , 5.75126961, 5.75965763,
#        5.76804565, 5.77643367, 5.78482168, 5.7932097 , 5.80159772,
#        5.80998573, 5.81837375, 5.82676177, 5.83514979, 5.8435378 ,
#        5.85192582, 5.86031384, 5.86870185, 5.87708987, 5.88547789,
#        5.89386591, 5.90225392, 5.91064194, 5.91902996, 5.92741797,
#        5.93580599, 5.94419401, 5.95258203, 5.96097004, 5.96935806,
#        5.97774608, 5.98613409, 5.99452211, 6.00291013, 6.01129815,
#        6.01968616, 6.02807418, 6.0364622 , 6.04485021, 6.05323823,
#        6.06162625, 6.07001427, 6.07840228, 6.0867903 , 6.09517832,
#        6.10356633, 6.11195435, 6.12034237, 6.12873039, 6.1371184 ,
#        6.14550642, 6.15389444, 6.16228245, 6.17067047, 6.17905849,
#        6.1874465 , 6.19583452, 6.20422254, 6.21261056, 6.22099857,
#        6.22938659, 6.23777461, 6.24616262, 6.25455064, 6.26293866,
#        6.27132668, 6.27971469, 6.28810271, 6.29649073, 6.30487874,
#        6.31326676, 6.32165478, 6.3300428 , 6.33843081, 6.34681883,
#        6.35520685, 6.36359486, 6.37198288, 6.3803709 , 6.38875892,
#        6.39714693, 6.40553495, 6.41392297, 6.42231098, 6.430699  ,
#        6.43908702, 6.44747504, 6.45586305, 6.46425107, 6.47263909,
#        6.4810271 , 6.48941512, 6.49780314, 6.50619116, 6.51457917,
#        6.52296719, 6.53135521, 6.53974322, 6.54813124, 6.55651926,
#        6.56490728, 6.57329529, 6.58168331, 6.59007133, 6.59845934,
#        6.60684736, 6.61523538, 6.6236234 , 6.63201141, 6.64039943,
#        6.64878745, 6.65717546, 6.66556348, 6.6739515 , 6.68233951,
#        6.69072753, 6.69911555, 6.70750357, 6.71589158, 6.7242796 ,
#        6.73266762, 6.74105563, 6.74944365, 6.75783167, 6.76621969,
#        6.7746077 , 6.78299572, 6.79138374, 6.79977175, 6.80815977,
#        6.81654779, 6.82493581, 6.83332382, 6.84171184, 6.85009986,
#        6.85848787, 6.86687589, 6.87526391, 6.88365193, 6.89203994,
#        6.90042796, 6.90881598, 6.91720399, 6.92559201, 6.93398003,
#        6.94236805, 6.95075606, 6.95914408, 6.9675321 , 6.97592011,
#        6.98430813, 6.99269615, 7.00108417, 7.00947218, 7.0178602 ,
#        7.02624822, 7.03463623, 7.04302425, 7.05141227, 7.05980029,
#        7.0681883 , 7.07657632, 7.08496434, 7.09335235, 7.10174037,
#        7.11012839, 7.11851641, 7.12690442, 7.13529244, 7.14368046,
#        7.15206847, 7.16045649, 7.16884451, 7.17723252, 7.18562054,
#        7.19400856, 7.20239658, 7.21078459, 7.21917261, 7.22756063,
#        7.23594864, 7.24433666, 7.25272468, 7.2611127 , 7.26950071,
#        7.27788873, 7.28627675, 7.29466476, 7.30305278, 7.3114408 ,
#        7.31982882, 7.32821683, 7.33660485, 7.34499287, 7.35338088,
#        7.3617689 , 7.37015692, 7.37854494, 7.38693295, 7.39532097,
#        7.40370899, 7.412097  , 7.42048502, 7.42887304, 7.43726106,
#        7.44564907, 7.45403709, 7.46242511, 7.47081312, 7.47920114,
#        7.48758916, 7.49597718, 7.50436519, 7.51275321, 7.52114123,
#        7.52952924, 7.53791726, 7.54630528, 7.5546933 , 7.56308131,
#        7.57146933, 7.57985735, 7.58824536, 7.59663338, 7.6050214 ,
#        7.61340942, 7.62179743, 7.63018545, 7.63857347, 7.64696148,
#        7.6553495 , 7.66373752, 7.67212553, 7.68051355, 7.68890157,
#        7.69728959, 7.7056776 , 7.71406562, 7.72245364, 7.73084165,
#        7.73922967, 7.74761769, 7.75600571, 7.76439372, 7.77278174,
#        7.78116976, 7.78955777, 7.79794579, 7.80633381, 7.81472183,
#        7.82310984, 7.83149786, 7.83988588, 7.84827389, 7.85666191,
#        7.86504993, 7.87343795, 7.88182596, 7.89021398, 7.898602  ,
#        7.90699001, 7.91537803, 7.92376605, 7.93215407, 7.94054208,
#        7.9489301 , 7.95731812, 7.96570613, 7.97409415, 7.98248217,
#        7.99087019, 7.9992582 , 8.00764622, 8.01603424, 8.02442225,
#        8.03281027, 8.04119829, 8.04958631, 8.05797432, 8.06636234,
#        8.07475036, 8.08313837, 8.09152639, 8.09991441, 8.10830243,
#        8.11669044, 8.12507846, 8.13346648, 8.14185449, 8.15024251,
#        8.15863053, 8.16701854, 8.17540656, 8.18379458, 8.1921826 ,
#        8.20057061, 8.20895863, 8.21734665, 8.22573466, 8.23412268,
#        8.2425107 , 8.25089872, 8.25928673, 8.26767475, 8.27606277,
#        8.28445078, 8.2928388 , 8.30122682, 8.30961484, 8.31800285,
#        8.32639087, 8.33477889, 8.3431669 , 8.35155492, 8.35994294,
#        8.36833096, 8.37671897, 8.38510699, 8.39349501, 8.40188302,
#        8.41027104, 8.41865906, 8.42704708, 8.43543509, 8.44382311,
#        8.45221113, 8.46059914, 8.46898716, 8.47737518, 8.4857632 ,
#        8.49415121, 8.50253923, 8.51092725, 8.51931526, 8.52770328,
#        8.5360913 , 8.54447932, 8.55286733, 8.56125535, 8.56964337,
#        8.57803138, 8.5864194 , 8.59480742, 8.60319544, 8.61158345,
#        8.61997147, 8.62835949, 8.6367475 , 8.64513552, 8.65352354,
#        8.66191155, 8.67029957, 8.67868759, 8.68707561, 8.69546362,
#        8.70385164, 8.71223966, 8.72062767, 8.72901569, 8.73740371,
#        8.74579173, 8.75417974, 8.76256776, 8.77095578, 8.77934379,
#        8.78773181, 8.79611983, 8.80450785, 8.81289586, 8.82128388,
#        8.8296719 , 8.83805991, 8.84644793, 8.85483595, 8.86322397,
#        8.87161198, 8.88      ])

# %%
valor2 = 1018214.19 - 368149.65 * numeros2 + 45764.86*numeros2**2

# %%
plt.scatter(x_test, y_test, s = 8, alpha = 0.5,  c = "deeppink")
plt.xlabel("Quantidade de cômodos")
plt.ylabel("Previsão dos valores das casas: dados de teste")
plt.plot(numeros2, valor2);

# %%
x_poly_test = grau_poly.fit_transform(x_test)

# %%
polynomial_test = LinearRegression()

# %%
polynomial_test.fit(x_poly_test, y_test);

# %%
# Coeficiente de determinação dos dados de teste
polynomial_test.score(x_poly_test, y_test)
# Out:
# 0.4946637345571433

# %%
previsoes_test = polynomial_test.predict(x_poly_test)

# %% [markdown]
# **Métricas**

# %%
mean_absolute_error(y_test, previsoes_test)
# Out:
# 81599.00235718951

# %%
mean_squared_error(y_test, previsoes_test)
# Out:
# 11261390933.071852

# %%
np.sqrt(mean_squared_error(y_test, previsoes_test))
# Out:
# 106119.70096580489
